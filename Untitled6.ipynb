# %% [markdown]
# ## Тестовый Notebook для GitHub

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
x = np.linspace(-10,10, 1e3)
y = np.exp(-(x-1)**2/4**2)
plt.plot(x,y)
# Out:
# <img src="data:image/png;base64,...">
